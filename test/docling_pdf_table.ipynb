# %%
import os
import pickle
import pandas as pd
from docling.document_converter import DocumentConverter
from time import time
from tqdm.auto import tqdm
from langchain_core.documents import Document

file_path = "../data/KR Notation Guide_2025.pdf"
lv1_cat, lv2_cat = "Rule", "KR"

path = file_path.replace("\\", "/")
filename = path.split("/")[-1]
first_sentence = f"This page explains {filename.replace(".pdf", "")} that belongs to {lv1_cat} and  {lv2_cat} categories.\n"


start_time = time()
doc_converter = DocumentConverter()
conv_res = doc_converter.convert(file_path)
tables = []
# Export table by
for table_ix, table in tqdm(enumerate(conv_res.document.tables)):
    page_num = table.prov[0].page_no if table.prov else "Unknown"
    table_df: pd.DataFrame = table.export_to_dataframe()
    extracted_table = first_sentence + table_df.to_markdown()
    lang_table = Document(page_content=extracted_table, metadata={'filename': filename, 'lv1_cat': lv1_cat, 'lv2_cat': lv2_cat, 'page':str(page_num)})
    tables.append(lang_table)

parsed_foldername = f"{lv1_cat}_{lv2_cat}"
if not os.path.exists(f"../docs/{parsed_foldername}_tables"):
    os.makedirs(f"../docs/{parsed_foldername}_tables")

parsed_filename = filename.replace(".pdf", "")
with open(f"../docs/{parsed_foldername}_tables/{parsed_filename}.pkl", 'ab') as file:
    pickle.dump(tables, file)
        

end_time = time() - start_time
print(f"Document converted and tables exported in {end_time:.2f} seconds.")
# Out:
# 2025-10-08 09:14:40,017 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-10-08 09:14:40,062 - INFO - Going to convert document batch...
# 2025-10-08 09:14:40,064 - INFO - Initializing pipeline for StandardPdfPipeline with options hash e647edf348883bed75367b22fbe60347
# 2025-10-08 09:14:40,068 - INFO - Accelerator device: 'cpu'
# 2025-10-08 09:14:42,797 - INFO - Accelerator device: 'cpu'
# 2025-10-08 09:14:44,641 - INFO - Accelerator device: 'cpu'
# 2025-10-08 09:14:45,588 - INFO - Processing document KR Notation Guide_2025.pdf
# 2025-10-08 09:40:02,338 - INFO - Finished converting document KR Notation Guide_2025.pdf in 1522.34 sec.
# 2025-10-08 09:40:02,342 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,348 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,351 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,353 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,356 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,359 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,361 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,363 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,366 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,367 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,369 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,370 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,372 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,373 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,376 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,378 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,381 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,382 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,383 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,386 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,388 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,389 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,392 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,394 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,397 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,399 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,401 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,404 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,405 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,407 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,409 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,413 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,415 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,417 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,420 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,422 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,423 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,425 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,428 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,432 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,433 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,436 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,438 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,442 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,447 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,450 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,452 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,453 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,458 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,460 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,463 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,469 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,482 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,486 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,487 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,490 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,493 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,496 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,501 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,510 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,512 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,517 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,519 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,522 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,525 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,526 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,528 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,532 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,534 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,540 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,542 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,543 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,547 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,550 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,553 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,555 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,558 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,561 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,565 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,568 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,569 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,572 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,575 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,578 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,583 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,585 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,588 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,593 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,596 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,600 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,603 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,606 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,609 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,612 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,616 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,619 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,622 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,624 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,628 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,635 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,637 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,641 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,644 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,647 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,652 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,654 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,657 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,659 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,662 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,665 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,668 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,670 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,672 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,675 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,678 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,682 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,684 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,687 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,689 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,693 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,695 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,699 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,702 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,704 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,707 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,711 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,715 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,718 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,721 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,723 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,726 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,729 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,733 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,736 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,741 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,742 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,746 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,749 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,751 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,754 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,755 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,757 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,759 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,761 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,765 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,768 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,771 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,779 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,782 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,785 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,789 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,791 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,793 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,795 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,799 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,801 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,803 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,806 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,809 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,810 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,812 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,816 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,819 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,823 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,825 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,829 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,833 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,836 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,838 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,857 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,858 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,860 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,862 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,870 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,874 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,875 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,877 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,879 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,881 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,882 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,884 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,885 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,891 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,894 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,895 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,899 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,901 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,905 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,908 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,910 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,912 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,915 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,916 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,919 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,922 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,925 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,928 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,931 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,932 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,935 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,938 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,942 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,947 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,955 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,962 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,966 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,968 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,972 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,977 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,980 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,986 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,991 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,994 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:02,999 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:03,006 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:03,011 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:03,016 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:03,021 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:03,028 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:03,042 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:03,053 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:03,070 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:03,077 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:03,083 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:03,088 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:03,093 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:03,095 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:03,103 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:03,110 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:03,118 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:03,121 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:03,125 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:03,132 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:03,133 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:03,137 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:03,138 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:03,141 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:03,145 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# 2025-10-08 09:40:03,147 - WARNING - Usage of TableItem.export_to_dataframe() without `doc` argument is deprecated.
# Document converted and tables exported in 1523.22 seconds.

# %%
import pickle

# Open the file containing the pickled data in binary read mode ('rb')
with open('../docs/Rule_KR_tables/KR Notation Guide_2025.pkl', 'rb') as file:
    # Load the pickled object from the file
    loaded_object = pickle.load(file)

# %%
len(loaded_object)
# Out:
# 239

# %%
loaded_object[:5]
# Out:
# [Document(metadata={'filename': 'KR Notation Guide_2025.pdf', 'lv1_cat': 'Rule', 'lv2_cat': 'KR', 'page': '2'}, page_content='This page explains KR Notation Guide_2025 that belongs to Rule and  KR categories.\n|    | 0                                                                                                                            | 1                                                                                                                                |\n|---:|:-----------------------------------------------------------------------------------------------------------------------------|:---------------------------------------------------------------------------------------------------------------------------------|\n|  0 | CHAPTER 1                                                                                                                    | GENERAL ··········································································································· 1            |\n|  1 | CHAPTER 2                                                                                                                    |                                                                                                                                  |\n|  2 | 2-1 SHIP TYPE - SPECIAL FEATURE                                                                                              | NOTATIONS ····················································· 5                                                                |\n|  3 | 1. Oil                                                                                                                       | Tanker ······················································································································· 5 |\n|  4 | 2-1. Liquefied Gas Carrier                                                                                                   | ·····························································································11                                  |\n|  5 | 2-2. Compressed Natural Gas Carrier                                                                                          | ········································································ 20                                                      |\n|  6 | 3-1. Chemical Tanker                                                                                                         | ·····································································································24                          |\n|  7 | 3-2. NLS Tanker                                                                                                              | ··············································································································32                 |\n|  8 | 4. Oil/Chemical Tanker                                                                                                       | ···································································································35                            |\n|  9 | 5. Bulk Carrier                                                                                                              | ··················································································································45             |\n| 10 | 6. Cargo Ship                                                                                                                | ····················································································································53           |\n| 11 | 7. Ore Carrier                                                                                                               | ···················································································································58            |\n| 12 | 8-1 Ore/Oil Carrier                                         ...
#  Document(metadata={'filename': 'KR Notation Guide_2025.pdf', 'lv1_cat': 'Rule', 'lv2_cat': 'KR', 'page': '3'}, page_content='This page explains KR Notation Guide_2025 that belongs to Rule and  KR categories.\n|    | 0                                                                                                                               | 1   |\n|---:|:--------------------------------------------------------------------------------------------------------------------------------|:----|\n|  0 | 27-2. Dock Gate ············································································································    | 179 |\n|  1 | 27-3. Launching Skid Barge ·······················································································              | 181 |\n|  2 | 28. Refrigerated Cargo Carrier ····················································································             | 183 |\n|  3 | 29. Single Point Mooring ·····························································································          | 185 |\n|  4 | 30. Floating Structure ···································································································      | 189 |\n|  5 | 31. Shiplift and Transfer System ···············································································                | 192 |\n|  6 | 32. WIG Craft ················································································································· | 195 |\n|  7 | 33. Floating LNG Bunkering Terminal ·······································································                     | 199 |\n|  8 | 34-1. Moored Oil Storage Tanker ·············································································                   | 201 |\n|  9 | 34-2. Moored Oil Storage Unit ··················································································                | 203 |\n| 10 | 2-2 Remarks of SHIP TYPE - SPECIAL FEATURE NOTATIONS ························                                                   | 205 |\n| 11 | CHAPTER 3 ADDITIONAL SPECIAL FEATURE NOTATIONS ·····································                                            | 220 |\n| 12 | CHAPTER 4 ADDITIONAL INSTALLATION NOTATIONS ··········································                                          | 231 |\n| 13 | Annex 1 Written Examples of Class Notations ·····························································235                    |     |'),
#  Document(metadata={'filename': 'KR Notation Guide_2025.pdf', 'lv1_cat': 'Rule', 'lv2_cat': 'KR', 'page': '7'}, page_content="This page explains KR Notation Guide_2025 that belongs to Rule and  KR categories.\n|    | Ship Type Notations                                                       | Special Feature Notations                           |\n|---:|:--------------------------------------------------------------------------|:----------------------------------------------------|\n|  0 | Oil Tanker 'ESP' (Double Hull) (Double Hull)(EXP) (FAC) (FAO) (FBC) (CSR) | Crude Product Crude/Product Product/Asphalt Asphalt |"),
#  Document(metadata={'filename': 'KR Notation Guide_2025.pdf', 'lv1_cat': 'Rule', 'lv2_cat': 'KR', 'page': '8'}, page_content="This page explains KR Notation Guide_2025 that belongs to Rule and  KR categories.\n|    | Notations                          | Design     | Survey                     |\n|---:|:-----------------------------------|:-----------|:---------------------------|\n|  0 | Oil Tanker                         | Pt 7 Ch 1  | Pt 1 Ch 2                  |\n|  1 | Oil Tanker(Double Hull)            | Pt 7 Ch 10 | Pt 1 Ch 2                  |\n|  2 | Oil Tanker(Double Hull)(EXP)       | Pt 7 Ch 10 | Pt 1 Ch 2                  |\n|  3 | Oil Tanker 'ESP'                   | Pt 7 Ch 1  | Pt 1 Ch 2, Pt 1 Ch 3 Sec 3 |\n|  4 | Oil Tanker(Double Hull) 'ESP'      | Pt 7 Ch 10 | Pt 1 Ch 2, Pt 1 Ch 3 Sec 5 |\n|  5 | Oil Tanker(Double Hull)(EXP) 'ESP' | Pt 7 Ch 10 | Pt 1 Ch 2, Pt 1 Ch 3 Sec 5 |"),
#  Document(metadata={'filename': 'KR Notation Guide_2025.pdf', 'lv1_cat': 'Rule', 'lv2_cat': 'KR', 'page': '10'}, page_content='This page explains KR Notation Guide_2025 that belongs to Rule and  KR categories.\n|    | Notations   | Design           | Survey   |\n|---:|:------------|:-----------------|:---------|\n|  0 | (FAC)       | Pt 7 Ch 1 Sec 10 | -        |\n|  1 | (FAO)       | Pt 7 Ch 1 Sec 10 | -        |\n|  2 | (FBC)       | Pt 7 Ch 1 Sec 10 | -        |')]

# %%
from IPython.display import Markdown
Markdown(loaded_object[7].page_content)
# Out:
# This page explains KR Notation Guide_2025 that belongs to Rule and  KR categories.
# |    | Ship Type Notations   | Special Feature Notations.Type of Ship   | Special Feature Notations.Type of Tank   | Special Feature Notations.Transportation Mode   | Special Feature Notations.Design Aspect and/or Primary Cargo           | Special Feature Notations.IMO Code   |
# |---:|:----------------------|:-----------------------------------------|:-----------------------------------------|:------------------------------------------------|:-----------------------------------------------------------------------|:-------------------------------------|
# |  0 | Liquefied Gas Carrier | 1G 2G 2PG 3G                             | 2I 3M 3S 1A 1B 1C                        | (R) (P) (RP)                                    | Maximum Vapour Pressure, Minimum Temperature and Specific Gravity (SG) | (NIGC) (IGC) (GC) (GCX)              |
# |  1 | Liquefied Gas Carrier | 1G 2G 2PG 3G                             | NV                                       | (R) (P) (RP)                                    | Name of Liquefied Gas primarily carried                                | (NIGC) (IGC) (GC) (GCX)              |
# |  2 | Liquefied Gas Carrier | LPG                                      | LPG                                      | LPG                                             | LPG                                                                    | LPG                                  |
